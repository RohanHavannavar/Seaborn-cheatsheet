# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')
#sns.set_style(style=None, rc=None)

# %%
sns.despine()
'''sns.despine(
    fig=None,
    ax=None,
    top=True,
    right=True,
    left=False,
    bottom=False,
    offset=None,
    trim=False,
)
'''
# Out:
# 'sns.despine(\n    fig=None,\n    ax=None,\n    top=True,\n    right=True,\n    left=False,\n    bottom=False,\n    offset=None,\n    trim=False,\n)\n'

# %%
sns.color_palette()
#sns.color_palette(palette=None, n_colors=None, desat=None)
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
#univariate analysis
#single variable plot

#sns.distplot()

sns.distplot()

'''
sns.distplot(
    a,
    bins=None,
    hist=True,
    kde=True,
    rug=False,
    fit=None,
    hist_kws=None,
    kde_kws=None,
    rug_kws=None,
    fit_kws=None,
    color=None,
    vertical=False,
    norm_hist=False,
    axlabel=None,
    label=None,
    ax=None,
)
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-111abac4f175> in <module>
#       4 #sns.distplot()
#       5
# ----> 6 sns.distplot()
#       7
#       8 '''
#
# TypeError: distplot() missing 1 required positional argument: 'a'

# %%
data = sns.load_dataset('iris')

# %%
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
sns.distplot(data['sepal_length'],kde=False)

# %%
sns.distplot(data['petal_length'],bins=10)

# %%
sns.set_style('ticks')
sns.distplot(data['petal_length'],hist=False)

# %%
#bivariate analysis
#two variable plot

#jointplot

sns.jointplot(x='petal_length',y='petal_width',data=data)

# %%
'''
sns.jointplot(
    x,
    y,
    data=None,
    kind='scatter',
    stat_func=None,
    color=None,
    height=6,
    ratio=5,
    space=0.2,
    dropna=True,
    xlim=None,
    ylim=None,
    joint_kws=None,
    marginal_kws=None,
    annot_kws=None,
    **kwargs,
)
'''
# Out:
# "\nsns.jointplot(\n    x,\n    y,\n    data=None,\n    kind='scatter',\n    stat_func=None,\n    color=None,\n    height=6,\n    ratio=5,\n    space=0.2,\n    dropna=True,\n    xlim=None,\n    ylim=None,\n    joint_kws=None,\n    marginal_kws=None,\n    annot_kws=None,\n    **kwargs,\n)\n"

# %%
#relplot or relationplot
sns.relplot(x='sepal_length',y='sepal_width',hue='species',data=data,kind='line')

# %%
#pairplots




'''
sns.pairplot(
    data,
    hue=None,
    hue_order=None,
    palette=None,
    vars=None,
    x_vars=None,
    y_vars=None,
    kind='scatter',
    diag_kind='auto',
    markers=None,
    height=2.5,
    aspect=1,
    corner=False,
    dropna=True,
    plot_kws=None,
    diag_kws=None,
    grid_kws=None,
    size=None,
)

'''
# Out:
# "\nsns.pairplot(\n    data,\n    hue=None,\n    hue_order=None,\n    palette=None,\n    vars=None,\n    x_vars=None,\n    y_vars=None,\n    kind='scatter',\n    diag_kind='auto',\n    markers=None,\n    height=2.5,\n    aspect=1,\n    corner=False,\n    dropna=True,\n    plot_kws=None,\n    diag_kws=None,\n    grid_kws=None,\n    size=None,\n)\n\n"

# %%
sns.set_style('darkgrid')
sns.pairplot(data,hue='species',kind='scatter',diag_kind='kde')

# %%
#plotting categorical data
#hexbin and kde plots are used for continous variables

#striplot and swarmplot are used for categorical data

sns.stripplot('species','petal_length',data=data)

# %%
#distribution of plots with each categories

#boxplot

data = sns.load_dataset('iris')
sns.boxplot(x='species',y='petal_length',data=data)

# %%
#voilinplot

# %%
#statistical estimation

#estimation of central limit theorem

#barplot() it is a relation between categorical and continous vriable
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#countplot and pointplot
